# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import rc
from matplotlib import gridspec
import cmath
import scipy as scipy
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap
from ast import literal_eval    

plt.style.use('/Users/paolostornati/Phd/phdthesis.mpltstyle')
niceblack="#262626"
from matplotlib.colors import ListedColormap
from palettable.cartocolors.sequential import DarkMint_7
import palettable
cmap = ListedColormap(DarkMint_7.mpl_colors)
colors_mint = cmap.colors
# from palettable.colorbrewer.sequential import Blues_8

cmap = ListedColormap(palettable.cmocean.sequential.Amp_20.mpl_colors)
reds = cmap.colors

cmap = ListedColormap(palettable.cmocean.diverging.Balance_14.mpl_colors)
balance14 = cmap.colors

cmap = ListedColormap(palettable.matplotlib.Inferno_20.mpl_colors)
inferno = cmap.colors

# %%
df_0_291=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/negative_lambda/obs_L_64_negative_Lambda/L64/mu0.291/result.cvs",delimiter="  ")

# %%
#mu0.291 mu0.313	mu0.319	mu1.28	mu1.29	mu1.3	mu1.92	mu1.925	mu1.93

df_0_291=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/negative_lambda/obs_L_64_negative_Lambda/L64/mu0.291/result.cvs",delimiter="  ")
df_0_313=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/negative_lambda/obs_L_64_negative_Lambda/L64/mu0.313/result.cvs",delimiter="  ",engine='python')
df_0_319=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/negative_lambda/obs_L_64_negative_Lambda/L64/mu0.319/result.cvs",delimiter="  ")
df_1_28=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/negative_lambda/obs_L_64_negative_Lambda/L64/mu1.28/result.cvs",delimiter="  ")
df_1_29=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/negative_lambda/obs_L_64_negative_Lambda/L64/mu1.29/result.cvs",delimiter="  ")
df_1_3=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/negative_lambda/obs_L_64_negative_Lambda/L64/mu1.3/result.cvs",delimiter="  ")
df_1_91=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/negative_lambda/obs_L_64_negative_Lambda/L64/mu1.91/result.cvs",delimiter="  ")
df_1_92=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/negative_lambda/obs_L_64_negative_Lambda/L64/mu1.92/result.cvs",delimiter="  ")
df_1_925=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/negative_lambda/obs_L_64_negative_Lambda/L64/mu1.925/result.cvs",delimiter="  ")
df_1_93=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/negative_lambda/obs_L_64_negative_Lambda/L64/mu1.93/result.cvs",delimiter="  ")
# Out:
# /Users/paolostornati/opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
df_0_291.columns
# Out:
# Index(['flipp_up', 'flipp_bot', 'mag', 'E_up', 'E_bot'], dtype='object')

# %%
df_0_313["flipp_up"].values
# Out:
# array([8.61684466e-01, 1.39596800e-13, 3.62272751e-15, 1.69122952e-01,
#        7.29843091e-01, 2.11517571e-13, 7.68804368e-13, 9.41471801e-02,
#        8.50466650e-01, 2.17744344e-15, 4.36018791e-16, 1.63212108e-01,
#        7.29884245e-01, 7.35327502e-14, 5.46455436e-13, 9.00356822e-02,
#        8.56265780e-01, 4.24498153e-15, 2.98818801e-14, 1.71748024e-01,
#        7.15791062e-01, 8.53391154e-16, 9.46169541e-14, 8.66697266e-02,
#        8.60673744e-01, 2.61157854e-16, 1.74513777e-13, 1.77447485e-01,
#        7.07369238e-01, 4.59087876e-17, 2.19645812e-15, 8.52930804e-02,
#        8.61962636e-01, 3.58919706e-18, 8.14971433e-17, 1.79004364e-01,
#        7.06252562e-01, 7.62689232e-18, 1.37129549e-16, 8.61880557e-02,
#        8.59702837e-01, 6.12250368e-19, 1.01601830e-16, 1.76347342e-01,
#        7.12277245e-01, 6.43927060e-18, 5.03097142e-17, 8.94542892e-02,
#        8.53703021e-01, 9.46478869e-17, 1.27161169e-18, 1.69976195e-01,
# ...

# %%
plt.plot(df_0_313["E_bot"].values)
plt.plot(df_0_313["E_up"].values)

plt.plot(df_0_313["mag"].values*10)

# %%
plt.plot(df_0_313["flipp_bot"].values)
plt.plot(df_0_313["flipp_up"].values)

# %%
plt.plot(df_1_93["E_bot"].values)
plt.plot(df_1_93["E_up"].values)

plt.plot(df_1_93["E_bot"].values+df_1_93["E_up"].values)

# %%
plt.plot(df_1_91["E_bot"].values)
plt.plot(df_1_91["E_up"].values)
plt.plot(df_1_91["mag"].values*3-2.5)

# %%
plt.plot(df_1_91["flipp_bot"].values)
plt.plot(df_1_91["flipp_up"].values)

# %%
plt.plot(df_1_3["E_bot"].values)
plt.plot(df_1_3["E_up"].values)
plt.plot(df_1_3["mag"].values)

# %%
sum(df_1_3["mag"].values)
# Out:
# 31.999927333586843

# %%
plt.plot(df_1_29["flipp_bot"].values)
plt.plot(df_1_29["flipp_up"].values)

# %%
plt.plot(df_0_291["E_bot"].values)
plt.plot(df_0_291["E_up"].values)
plt.plot(df_0_291["mag"].values)

# %%
plt.plot(df_0_291["mag"].values)
