# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import rc
from matplotlib import gridspec
import cmath
import scipy as scipy
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap
from ast import literal_eval    

plt.style.use('/Users/paolostornati/Phd/phdthesis.mpltstyle')
niceblack="#262626"
from matplotlib.colors import ListedColormap
from palettable.cartocolors.sequential import DarkMint_7
import palettable
cmap = ListedColormap(DarkMint_7.mpl_colors)
colors_mint = cmap.colors
# from palettable.colorbrewer.sequential import Blues_8

cmap = ListedColormap(palettable.cmocean.sequential.Amp_20.mpl_colors)
reds = cmap.colors

cmap = ListedColormap(palettable.cmocean.diverging.Balance_14.mpl_colors)
balance14 = cmap.colors

cmap = ListedColormap(palettable.matplotlib.Inferno_20.mpl_colors)
inferno = cmap.colors

# %%
#mu0.291 mu0.313	mu0.319	mu1.28	mu1.29	mu1.3	mu1.92	mu1.925	mu1.93

df_0_291=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/obs_L64/mu0.291/result.cvs",delimiter="  ")
df_0_313=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/obs_L64/mu0.313/result.cvs",delimiter="  ",engine='python')
df_0_319=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/obs_L64/mu0.319/result.cvs",delimiter="  ")
df_1_28=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/obs_L64/mu1.28/result.cvs",delimiter="  ")
df_1_29=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/obs_L64/mu1.29/result.cvs",delimiter="  ")
df_1_3=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/obs_L64/mu1.3/result.cvs",delimiter="  ")
df_1_91=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/obs_L64/mu1.91/result.cvs",delimiter="  ")
df_1_92=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/obs_L64/mu1.92/result.cvs",delimiter="  ")
df_1_925=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/obs_L64/mu1.925/result.cvs",delimiter="  ")
df_1_93=pd.read_csv("/Users/paolostornati/Phd/SquareIce/02_DMRG/L_64/obs_L64/mu1.93/result.cvs",delimiter="  ")
# Out:
# /Users/paolostornati/opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
df_0_291.columns
# Out:
# Index(['flipp_up', 'flipp_bot', 'mag', 'E_up', 'E_bot'], dtype='object')

# %%
df_0_313["flipp_up"].values
# Out:
# array([7.59682448e-01, 1.36845345e-17, 5.47748006e-22, 1.16116472e-01,
#        8.23103857e-01, 1.37220287e-15, 1.01893755e-19, 1.57880825e-01,
#        7.39133290e-01, 3.14665444e-19, 1.97212334e-18, 9.30780723e-02,
#        8.52139582e-01, 7.07898211e-19, 9.91652687e-19, 1.67609905e-01,
#        7.22416777e-01, 6.31816966e-18, 8.97619923e-20, 8.81606323e-02,
#        8.58782998e-01, 7.95183391e-18, 5.89944069e-19, 1.75085418e-01,
#        7.10699687e-01, 2.66248392e-18, 1.45089080e-18, 8.57109633e-02,
#        8.61740116e-01, 5.39147968e-18, 3.65280461e-18, 1.78764666e-01,
#        7.05881601e-01, 1.41371485e-16, 6.10021350e-19, 8.54466256e-02,
#        8.61293328e-01, 5.81939384e-17, 5.87802727e-20, 1.78182013e-01,
#        7.08422988e-01, 9.30798540e-18, 1.25660391e-18, 8.75249465e-02,
#        8.57173549e-01, 1.38560624e-18, 6.22339568e-19, 1.73578161e-01,
#        7.17655751e-01, 6.16286721e-18, 7.25497615e-18, 9.19648308e-02,
#        8.49301109e-01, 3.91530474e-18, 1.61066647e-16, 1.65658295e-01,
#        7.32179657e-01, 3.69491829e-17, 2.22327965e-17, 9.86384352e-02,
#        8.37818879e-01, 6.14397667e-20, 3.45657929e-17, 1.55392863e-01,
#        0.00000000e+00])

# %%
plt.plot(df_0_313["E_bot"].values)
plt.plot(df_0_313["E_up"].values)

plt.plot(df_0_313["mag"].values*10)

# %%
plt.plot(df_0_313["flipp_bot"].values)
plt.plot(df_0_313["flipp_up"].values)

# %%
plt.plot(df_1_93["E_bot"].values)
plt.plot(df_1_93["E_up"].values)

plt.plot(df_1_93["E_bot"].values+df_1_93["E_up"].values)

# %%
plt.plot(df_1_91["E_bot"].values)
plt.plot(df_1_91["E_up"].values)
plt.plot(df_1_91["mag"].values*3-2.5)

# %%
plt.plot(df_1_91["flipp_bot"].values)
plt.plot(df_1_91["flipp_up"].values)

# %%
plt.plot(df_1_3["E_bot"].values)
plt.plot(df_1_3["E_up"].values)
plt.plot(df_1_3["mag"].values)

# %%
sum(df_1_3["mag"].values)
# Out:
# 31.00000003162723

# %%
plt.plot(df_1_31["flipp_up"].values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-15717fc34122> in <module>
# ----> 1 plt.plot(df_1_31["flipp_up"].values)
#       2
#       3
#
# NameError: name 'df_1_31' is not defined

# %%
plt.plot(df_1_29["flipp_bot"].values)

# %%
plt.plot(df_0_291["E_bot"].values)
plt.plot(df_0_291["E_up"].values)
plt.plot(df_0_291["mag"].values)

# %%
plt.plot(df_0_291["mag"].values)
